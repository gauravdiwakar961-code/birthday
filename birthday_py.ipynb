# %%
name = input("Enter the birthday girl's name: ")
age = int(input("Enter her age: "))

# Function for correct suffix
def suffix(n):
    if 11 <= n % 100 <= 13:
        return "th"
    return {1: "st", 2: "nd", 3: "rd"}.get(n % 10, "th")

print("\n🎉🎂 Happy Birthday 🎂🎉")
print(f"Dear {name},")
print(f"Wishing you a very happy {age}{suffix(age)} birthday!")
print("May your day be filled with love, laughter, and lots of cake! 🎂")
print("May all your dreams come true and may you always keep smiling 😊")
print("Have a wonderful year ahead! 💖✨")
# Out:
# Enter the birthday girl's name: khushi
# Enter her age: 24
#
# 🎉🎂 Happy Birthday 🎂🎉
# Dear khushi,
# Wishing you a very happy 24th birthday!
# May your day be filled with love, laughter, and lots of cake! 🎂
# May all your dreams come true and may you always keep smiling 😊
# Have a wonderful year ahead! 💖✨
